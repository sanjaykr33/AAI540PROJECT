# %% [markdown]
# # Employee Attrition Prediction
# ## Notebook 03: Model Training using AWS SageMaker
#
# This notebook covers:
# - Loading processed datasets from Amazon S3
# - Training an XGBoost classification model using SageMaker
# - Saving trained model artifacts to S3
#
# No data preprocessing or feature engineering is performed here.

# %% [markdown]
# Basic imports

# %%
import sagemaker
import boto3
from sagemaker.session import Session
from sagemaker.inputs import TrainingInput
from sagemaker.image_uris import retrieve
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %% [markdown]
# SageMaker Session Setup

# %%
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()
bucket = sagemaker_session.default_bucket()
region = boto3.Session().region_name

print("Bucket:", bucket)
print("Region:", region)
print("Role:", role)
# Out:
# Bucket: sagemaker-us-east-1-952878272094
# Region: us-east-1
# Role: arn:aws:iam::952878272094:role/LabRole

# %% [markdown]
# Defining S3 Paths for Processed Data

# %%
processed_prefix = "employee-attrition/processed"

train_data_path = f"s3://{bucket}/{processed_prefix}/train.csv"
val_data_path   = f"s3://{bucket}/{processed_prefix}/validation.csv"

print("Train path:", train_data_path)
print("Validation path:", val_data_path)
# Out:
# Train path: s3://sagemaker-us-east-1-952878272094/employee-attrition/processed/train.csv
# Validation path: s3://sagemaker-us-east-1-952878272094/employee-attrition/processed/validation.csv

# %% [markdown]
# Preparing SageMaker Training Inputs

# %%
train_input = TrainingInput(
    s3_data=train_data_path,
    content_type="text/csv"
)

validation_input = TrainingInput(
    s3_data=val_data_path,
    content_type="text/csv"
)

# %% [markdown]
# Getting XGBoost Container Image

# %%
xgb_image = retrieve(
    framework="xgboost",
    region=region,
    version="1.7-1"
)

print(xgb_image)
# Out:
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.7-1

# %% [markdown]
# Defining XGBoost Estimator

# %%
xgb_estimator = sagemaker.estimator.Estimator(
    image_uri=xgb_image,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    volume_size=30,
    max_run=3600,
    output_path=f"s3://{bucket}/employee-attrition/model-artifacts",
    sagemaker_session=sagemaker_session
)

# %% [markdown]
# Setting up Hyperparameters

# %%
xgb_estimator.set_hyperparameters(
    objective="binary:logistic",
    eval_metric="auc",
    num_round=200,
    max_depth=5,
    eta=0.1,
    subsample=0.8,
    colsample_bytree=0.8
)

# %% [markdown]
# Starting Training

# %%
xgb_estimator.fit(
    {
        "train": train_input,
        "validation": validation_input
    }
)
# Out:
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2026-02-19-21-45-42-632
# 2026-02-19 21:45:42 Starting - Starting the training job...
# 2026-02-19 21:46:08 Starting - Preparing the instances for training...
# 2026-02-19 21:46:30 Downloading - Downloading input data......
# 2026-02-19 21:47:21 Downloading - Downloading the training image......
# 2026-02-19 21:48:47 Training - Training image download completed. Training in progress.
# 2026-02-19 21:48:47 Uploading - Uploading generated training model/miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-19 21:48:31.557 ip-10-2-250-160.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2026-02-19 21:48:31.638 ip-10-2-250-160.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2026-02-19:21:48:31:INFO] Imported framework sagemaker_xgboost_container.training
# [2026-02-19:21:48:31:INFO] Failed to parse hyperparameter eval_metric value auc to Json.
# Returning the value itself
# [2026-02-19:21:48:31:INFO] Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# [2026-02-19:21:48:31:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-19:21:48:31:INFO] Running XGBoost Sagemaker in algorithm mode
# [2026-02-19:21:48:31:INFO] Determined 0 GPU(s) available on the instance.
# [2026-02-19:21:48:31:INFO] Determined delimiter of CSV input is ','
# [2026-02-19:21:48:31:INFO] Determined delimiter of CSV input is ','
# [2026-02-19:21:48:31:INFO] File path /opt/ml/input/data/train of input files
# [2026-02-19:21:48:31:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2026-02-19:21:48:31:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv2427435629030112129
# [2026-02-19:21:48:31:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-02-19:21:48:31:INFO] Determined delimiter of CSV input is ','
# [2026-02-19:21:48:32:INFO] File path /opt/ml/input/data/validation of input files
# [2026-02-19:21:48:32:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2026-02-19:21:48:32:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-7972556139139653493
# [2026-02-19:21:48:32:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-02-19:21:48:32:INFO] Determined delimiter of CSV input is ','
# [2026-02-19:21:48:32:INFO] Single node training.
# [2026-02-19:21:48:32:INFO] Train matrix has 41718 rows and 29 columns
# [2026-02-19:21:48:32:INFO] Validation matrix has 8940 rows
# [2026-02-19 21:48:32.110 ip-10-2-250-160.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2026-02-19 21:48:32.110 ip-10-2-250-160.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2026-02-19 21:48:32.111 ip-10-2-250-160.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2026-02-19 21:48:32.111 ip-10-2-250-160.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2026-02-19:21:48:32:INFO] Debug hook created from config
# [2026-02-19 21:48:32.213 ip-10-2-250-160.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2026-02-19 21:48:32.215 ip-10-2-250-160.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [0]#011train-auc:0.78707#011validation-auc:0.79355
# [1]#011train-auc:0.79210#011validation-auc:0.79895
# [2]#011train-auc:0.79502#011validation-auc:0.80196
# [3]#011train-auc:0.79583#011validation-auc:0.80219
# [4]#011train-auc:0.79763#011validation-auc:0.80463
# [5]#011train-auc:0.80062#011validation-auc:0.80694
# [6]#011train-auc:0.80315#011validation-auc:0.80954
# [7]#011train-auc:0.80600#011validation-auc:0.81206
# [8]#011train-auc:0.80715#011validation-auc:0.81347
# [9]#011train-auc:0.81204#011validation-auc:0.81777
# [10]#011train-auc:0.81261#011validation-auc:0.81834
# [11]#011train-auc:0.81382#011validation-auc:0.81940
# [12]#011train-auc:0.81491#011validation-auc:0.82017
# [13]#011train-auc:0.81663#011validation-auc:0.82164
# [14]#011train-auc:0.81977#011validation-auc:0.82433
# [15]#011train-auc:0.82151#011validation-auc:0.82579
# [16]#011train-auc:0.82247#011validation-auc:0.82688
# [17]#011train-auc:0.82431#011validation-auc:0.82866
# [18]#011train-auc:0.82525#011validation-auc:0.82928
# [19]#011train-auc:0.82697#011validation-auc:0.83072
# [20]#011train-auc:0.82842#011validation-auc:0.83207
# [21]#011train-auc:0.82924#011validation-auc:0.83270
# [22]#011train-auc:0.82962#011validation-auc:0.83323
# [23]#011train-auc:0.83137#011validation-auc:0.83461
# [24]#011train-auc:0.83261#011validation-auc:0.83564
# [25]#011train-auc:0.83344#011validation-auc:0.83610
# [26]#011train-auc:0.83384#011validation-auc:0.83649
# [27]#011train-auc:0.83468#011validation-auc:0.83696
# [28]#011train-auc:0.83518#011validation-auc:0.83743
# [29]#011train-auc:0.83613#011validation-auc:0.83808
# [30]#011train-auc:0.83701#011validation-auc:0.83845
# [31]#011train-auc:0.83761#011validation-auc:0.83868
# [32]#011train-auc:0.83777#011validation-auc:0.83875
# [33]#011train-auc:0.83850#011validation-auc:0.83915
# [34]#011train-auc:0.83923#011validation-auc:0.83959
# [35]#011train-auc:0.83974#011validation-auc:0.84000
# [36]#011train-auc:0.84031#011validation-auc:0.84049
# [37]#011train-auc:0.84065#011validation-auc:0.84051
# [38]#011train-auc:0.84098#011validation-auc:0.84073
# [39]#011train-auc:0.84152#011validation-auc:0.84097
# [40]#011train-auc:0.84182#011validation-auc:0.84101
# [41]#011train-auc:0.84241#011validation-auc:0.84121
# [42]#011train-auc:0.84265#011validation-auc:0.84148
# [43]#011train-auc:0.84324#011validation-auc:0.84184
# [44]#011train-auc:0.84355#011validation-auc:0.84201
# [45]#011train-auc:0.84386#011validation-auc:0.84210
# [46]#011train-auc:0.84394#011validation-auc:0.84227
# [47]#011train-auc:0.84443#011validation-auc:0.84253
# [48]#011train-auc:0.84451#011validation-auc:0.84256
# [49]#011train-auc:0.84480#011validation-auc:0.84269
# [50]#011train-auc:0.84504#011validation-auc:0.84268
# [51]#011train-auc:0.84531#011validation-auc:0.84276
# [52]#011train-auc:0.84559#011validation-auc:0.84290
# [53]#011train-auc:0.84594#011validation-auc:0.84308
# [54]#011train-auc:0.84607#011validation-auc:0.84306
# [55]#011train-auc:0.84642#011validation-auc:0.84319
# [56]#011train-auc:0.84656#011validation-auc:0.84320
# [57]#011train-auc:0.84680#011validation-auc:0.84327
# [58]#011train-auc:0.84707#011validation-auc:0.84341
# [59]#011train-auc:0.84728#011validation-auc:0.84365
# [60]#011train-auc:0.84740#011validation-auc:0.84357
# [61]#011train-auc:0.84768#011validation-auc:0.84366
# [62]#011train-auc:0.84798#011validation-auc:0.84379
# [63]#011train-auc:0.84825#011validation-auc:0.84385
# [64]#011train-auc:0.84848#011validation-auc:0.84384
# [65]#011train-auc:0.84862#011validation-auc:0.84389
# [66]#011train-auc:0.84885#011validation-auc:0.84393
# [67]#011train-auc:0.84904#011validation-auc:0.84395
# [68]#011train-auc:0.84926#011validation-auc:0.84404
# [69]#011train-auc:0.84942#011validation-auc:0.84407
# [70]#011train-auc:0.84972#011validation-auc:0.84407
# [71]#011train-auc:0.84995#011validation-auc:0.84416
# [72]#011train-auc:0.85005#011validation-auc:0.84431
# [73]#011train-auc:0.85027#011validation-auc:0.84431
# [74]#011train-auc:0.85048#011validation-auc:0.84431
# [75]#011train-auc:0.85059#011validation-auc:0.84432
# [76]#011train-auc:0.85075#011validation-auc:0.84438
# [77]#011train-auc:0.85092#011validation-auc:0.84441
# [78]#011train-auc:0.85121#011validation-auc:0.84439
# [79]#011train-auc:0.85144#011validation-auc:0.84441
# [80]#011train-auc:0.85156#011validation-auc:0.84443
# [81]#011train-auc:0.85173#011validation-auc:0.84454
# [82]#011train-auc:0.85195#011validation-auc:0.84448
# [83]#011train-auc:0.85216#011validation-auc:0.84448
# [84]#011train-auc:0.85239#011validation-auc:0.84453
# [85]#011train-auc:0.85259#011validation-auc:0.84452
# [86]#011train-auc:0.85283#011validation-auc:0.84452
# [87]#011train-auc:0.85296#011validation-auc:0.84451
# [88]#011train-auc:0.85309#011validation-auc:0.84457
# [89]#011train-auc:0.85335#011validation-auc:0.84471
# [90]#011train-auc:0.85350#011validation-auc:0.84464
# [91]#011train-auc:0.85374#011validation-auc:0.84461
# [92]#011train-auc:0.85399#011validation-auc:0.84458
# [93]#011train-auc:0.85415#011validation-auc:0.84458
# [94]#011train-auc:0.85441#011validation-auc:0.84451
# [95]#011train-auc:0.85465#011validation-auc:0.84458
# [96]#011train-auc:0.85478#011validation-auc:0.84459
# [97]#011train-auc:0.85503#011validation-auc:0.84459
# [98]#011train-auc:0.85524#011validation-auc:0.84459
# [99]#011train-auc:0.85542#011validation-auc:0.84466
# [100]#011train-auc:0.85559#011validation-auc:0.84460
# [101]#011train-auc:0.85579#011validation-auc:0.84446
# [102]#011train-auc:0.85596#011validation-auc:0.84442
# [103]#011train-auc:0.85615#011validation-auc:0.84430
# [104]#011train-auc:0.85625#011validation-auc:0.84436
# [105]#011train-auc:0.85650#011validation-auc:0.84437
# [106]#011train-auc:0.85668#011validation-auc:0.84434
# [107]#011train-auc:0.85683#011validation-auc:0.84437
# [108]#011train-auc:0.85705#011validation-auc:0.84439
# [109]#011train-auc:0.85718#011validation-auc:0.84429
# [110]#011train-auc:0.85734#011validation-auc:0.84426
# [111]#011train-auc:0.85753#011validation-auc:0.84427
# [112]#011train-auc:0.85767#011validation-auc:0.84425
# [113]#011train-auc:0.85780#011validation-auc:0.84431
# [114]#011train-auc:0.85796#011validation-auc:0.84424
# [115]#011train-auc:0.85810#011validation-auc:0.84431
# [116]#011train-auc:0.85832#011validation-auc:0.84432
# [117]#011train-auc:0.85846#011validation-auc:0.84427
# [118]#011train-auc:0.85867#011validation-auc:0.84417
# [119]#011train-auc:0.85884#011validation-auc:0.84419
# [120]#011train-auc:0.85904#011validation-auc:0.84419
# [121]#011train-auc:0.85927#011validation-auc:0.84418
# [122]#011train-auc:0.85944#011validation-auc:0.84414
# [123]#011train-auc:0.85969#011validation-auc:0.84418
# [124]#011train-auc:0.85990#011validation-auc:0.84410
# [125]#011train-auc:0.86009#011validation-auc:0.84411
# [126]#011train-auc:0.86036#011validation-auc:0.84408
# [127]#011train-auc:0.86059#011validation-auc:0.84405
# [128]#011train-auc:0.86077#011validation-auc:0.84412
# [129]#011train-auc:0.86098#011validation-auc:0.84413
# [130]#011train-auc:0.86116#011validation-auc:0.84420
# [131]#011train-auc:0.86123#011validation-auc:0.84422
# [132]#011train-auc:0.86141#011validation-auc:0.84423
# [133]#011train-auc:0.86153#011validation-auc:0.84422
# [134]#011train-auc:0.86180#011validation-auc:0.84422
# [135]#011train-auc:0.86191#011validation-auc:0.84416
# [136]#011train-auc:0.86208#011validation-auc:0.84409
# [137]#011train-auc:0.86225#011validation-auc:0.84403
# [138]#011train-auc:0.86246#011validation-auc:0.84394
# [139]#011train-auc:0.86263#011validation-auc:0.84386
# [140]#011train-auc:0.86270#011validation-auc:0.84388
# [141]#011train-auc:0.86281#011validation-auc:0.84387
# [142]#011train-auc:0.86291#011validation-auc:0.84388
# [143]#011train-auc:0.86313#011validation-auc:0.84382
# [144]#011train-auc:0.86326#011validation-auc:0.84382
# [145]#011train-auc:0.86340#011validation-auc:0.84371
# [146]#011train-auc:0.86362#011validation-auc:0.84366
# [147]#011train-auc:0.86374#011validation-auc:0.84353
# [148]#011train-auc:0.86390#011validation-auc:0.84348
# [149]#011train-auc:0.86398#011validation-auc:0.84351
# [150]#011train-auc:0.86412#011validation-auc:0.84347
# [151]#011train-auc:0.86431#011validation-auc:0.84352
# [152]#011train-auc:0.86445#011validation-auc:0.84346
# [153]#011train-auc:0.86461#011validation-auc:0.84347
# [154]#011train-auc:0.86478#011validation-auc:0.84353
# [155]#011train-auc:0.86495#011validation-auc:0.84347
# [156]#011train-auc:0.86512#011validation-auc:0.84343
# [157]#011train-auc:0.86528#011validation-auc:0.84340
# [158]#011train-auc:0.86549#011validation-auc:0.84333
# [159]#011train-auc:0.86563#011validation-auc:0.84330
# [160]#011train-auc:0.86581#011validation-auc:0.84325
# [161]#011train-auc:0.86598#011validation-auc:0.84335
# [162]#011train-auc:0.86611#011validation-auc:0.84333
# [163]#011train-auc:0.86631#011validation-auc:0.84331
# [164]#011train-auc:0.86646#011validation-auc:0.84328
# [165]#011train-auc:0.86657#011validation-auc:0.84321
# [166]#011train-auc:0.86680#011validation-auc:0.84321
# [167]#011train-auc:0.86703#011validation-auc:0.84322
# [168]#011train-auc:0.86713#011validation-auc:0.84324
# [169]#011train-auc:0.86732#011validation-auc:0.84320
# [170]#011train-auc:0.86741#011validation-auc:0.84319
# [171]#011train-auc:0.86756#011validation-auc:0.84311
# [172]#011train-auc:0.86760#011validation-auc:0.84308
# [173]#011train-auc:0.86778#011validation-auc:0.84310
# [174]#011train-auc:0.86787#011validation-auc:0.84310
# [175]#011train-auc:0.86798#011validation-auc:0.84309
# [176]#011train-auc:0.86807#011validation-auc:0.84303
# [177]#011train-auc:0.86823#011validation-auc:0.84303
# [178]#011train-auc:0.86841#011validation-auc:0.84292
# [179]#011train-auc:0.86849#011validation-auc:0.84295
# [180]#011train-auc:0.86864#011validation-auc:0.84292
# [181]#011train-auc:0.86884#011validation-auc:0.84298
# [182]#011train-auc:0.86898#011validation-auc:0.84295
# [183]#011train-auc:0.86905#011validation-auc:0.84292
# [184]#011train-auc:0.86918#011validation-auc:0.84294
# [185]#011train-auc:0.86937#011validation-auc:0.84297
# [186]#011train-auc:0.86954#011validation-auc:0.84298
# [187]#011train-auc:0.86969#011validation-auc:0.84300
# [188]#011train-auc:0.86982#011validation-auc:0.84295
# [189]#011train-auc:0.86999#011validation-auc:0.84298
# [190]#011train-auc:0.87016#011validation-auc:0.84292
# [191]#011train-auc:0.87031#011validation-auc:0.84294
# [192]#011train-auc:0.87054#011validation-auc:0.84286
# [193]#011train-auc:0.87072#011validation-auc:0.84285
# [194]#011train-auc:0.87093#011validation-auc:0.84276
# [195]#011train-auc:0.87112#011validation-auc:0.84270
# [196]#011train-auc:0.87133#011validation-auc:0.84263
# [197]#011train-auc:0.87153#011validation-auc:0.84261
# [198]#011train-auc:0.87158#011validation-auc:0.84260
# [199]#011train-auc:0.87178#011validation-auc:0.84261
#
# 2026-02-19 21:49:06 Completed - Training job completed
# Training seconds: 155
# Billable seconds: 155
